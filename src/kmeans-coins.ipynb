# %% [markdown]
# # Kmeans aplicación

# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
img = imread("monedas1.jpg")
plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.show()

# %%
s = img.shape
X = img.reshape(s[0] * s[1], s[2])
print(X.shape)
# Out:
# (235520, 3)

# %% [markdown]
# # Separar el objeto del fondo

# %%
K = 3
km = KMeans(K)
X_km = km.fit_predict(X)

# %%
Y = X_km.reshape(s[0],s[1])
plt.figure(figsize=(10, 10))
plt.imshow((Y.astype("uint8")))
plt.show()

# %% [markdown]
# # Aplicar K-means a los puntos de objetos

# %%
coin_points = np.where(Y>0)
coin_points
# Out:
# (array([  4,   4,   5, ..., 363, 364, 365]),
#  array([542, 546, 534, ...,  35,  33,  32]))

# %% [markdown]
# Pegamos las dos listas en una sola:

# %%
coin_points = np.concatenate([coin_points], axis=1).transpose()
coin_points.shape
# Out:
# (92398, 2)

# %%
coin_points
# Out:
# array([[  4, 542],
#        [  4, 546],
#        [  5, 534],
#        ...,
#        [363,  35],
#        [364,  33],
#        [365,  32]])

# %% [markdown]
# Se le aplica OTRO kmeans a los puntos de las monedas:

# %%
K = 8
km2 = KMeans(K)
km2.fit(coin_points)
coins = km2.cluster_centers_
coins
# Out:
# array([[ 93.95447886, 390.76799916],
#        [ 95.37543347,  83.31934051],
#        [ 95.62355551, 545.51955256],
#        [281.93619081,  86.96653992],
#        [280.34817054, 551.12227666],
#        [ 93.4318407 , 245.81127402],
#        [280.63917353, 392.3499916 ],
#        [277.97397692, 247.5270724 ]])

# %%
plt.imshow(img)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %% [markdown]
# # Más ejemplos

# %%
img2 = imread("monedas2.jpeg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
pred = km.predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %% [markdown]
# Aquí, el cluster 2 quedó en el fondo

# %%
monedas = 4
coin_points = np.where(pred<2)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %%
img2 = imread("monedas5.jpg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
pred = km.predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %%
monedas = 6
coin_points = np.where(pred>0)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %% [markdown]
# # Con otra imagen:

# %%
img2 = imread("monedas4.jpeg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
plt.imshow(img2)
plt.show()

# %% [markdown]
# El fondo no es liso

# %%
K = 4
km = KMeans(K)
X_km = km.fit_predict(X)
pred = km.predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %%
monedas = 14
coin_points = np.where(pred<2)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()
